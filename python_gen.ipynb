# %%
import random

PHONE_MODEL = [
('', 0,0,0,0,0),
('Samsung Galaxy S21 Ultra', 1, 121210, 52521, 1, 1),
('Samsung Galaxy S21 Plus', 1, 2210, 1120, 1, 2),
('Samsung Galaxy S21', 1, 3120, 1512, 1, 3),
('Samsung Galaxy S20 Ultra', 1, 4120, 2730, 1, 4),
('Samsung Galaxy S20', 1, 610, 310, 1, 5),
('iPhone 12 Pro Max', 2, 131230, 65123, 2, 6),
('iPhone 12 Pro', 2, 141230, 760, 2, 7),
('iPhone 12', 2, 1560, 756, 2, 8),
('iPhone 11 Pro Max', 2, 1660, 860, 3, 9),
('iPhone 11 Pro', 2, 1760, 856, 3, 10),
('iPhone 11', 2, 18120, 9120, 3, 11),
('Xiaomi Mi 11 Ultra', 3, 2280, 1180, 1, 12),
('Xiaomi Mi 11 Pro', 3, 2380, 1158, 1, 13),
('Xiaomi Mi 11 Lite', 3, 2480, 1280, 1, 14),
('Xiaomi Mi 10 Ultra', 3, 2580, 1258, 1, 15),
('Xiaomi Mi 10 Pro', 3, 2680, 13740, 1, 16),
('vivo X60 Pro', 4, 2940, 1454, 5, 17),
('vivo X60', 4, 344, 1540, 5, 18),
('vivo X50 Pro', 4, 311230, 155123, 5, 19),
('vivo X50', 4, 321230, 161230, 5, 20)]

# %%
# for each phone model, generate the data with this pattern:
# there are 1-3 color options, and each color option has 1-3 storage/ram options
# the price must follow the pattern: each phone model from the same manufacturer, the one appears first has the highest price, and the price decreases as the phone model appears later
# the price is in VND, and should be a multiple of 1000
# in one phone model, the price of the same storage/ram option is the same
# the name is the combination of the model name, color and storage/ram option
# the hexColorID can be Blue: 255, Red: 16711680, Gold: 16777215, Black: 0, Silver: 16777215, Purple: 8388736, Green: 32768.
# the storage option is in GB, can be 64, 128, 256, 512
# the ram option is in GB, can be 4, 6, 8, 12, 16
# save the data to a list of tuples, phone_model_option(phoneModelID, price, name, hexColorID, storage, ram)

# for example, one of the elements in the list should be: (1, 29999000, 'Samsung Galaxy S21 Ultra Gold 8/128GB', 16777215, 128, 8)

COLOR_ID = [('Blue', 255), ('Red', 16711680), ('Gold', 16766720), ('Black', 0), ('Silver', 16777215), ('Purple', 8388736), ('Green', 32768)]
STORAGE_OPTION = [64, 128, 256, 512]
RAM_OPTION = [4, 6, 8, 12, 16]

phone_model_option = [(0, 0, '', 0, 0, 0)]
price = 29990000
for i in range(1, len(PHONE_MODEL)):
    # check if manufacturer changed to reset the price
    if PHONE_MODEL[i][1] != PHONE_MODEL[i - 1][1]:
        price = 29990000
    price -= random.randint(100, 400)*20000

    # shuffle color, storage, ram options
    random.shuffle(COLOR_ID)
    random.shuffle(STORAGE_OPTION)
    random.shuffle(RAM_OPTION)

    for j in range(random.randint(1, 3)):     # j = color option
        for k in range(random.randint(1, 3)): # k = storage option
            # price calculation
            hexColorID = COLOR_ID[j][1]
            storage = STORAGE_OPTION[k]
            ram = RAM_OPTION[k]
            priceFinal = price + storage*random.randint(1, 6)*1000 + ram*random.randint(10, 40)*3000
            name = PHONE_MODEL[i][0] + ' ' + COLOR_ID[j][0] + ' ' + str(ram) + '/' + str(storage) + 'GB'
            
            phone_model_option.append((i, priceFinal, name, hexColorID, storage, ram))

phone_model_option[-10::]
# Out:
# [(19, 15642000, 'vivo X50 Pro Blue 16/64GB', 255, 64, 16),
#  (19, 14554000, 'vivo X50 Pro Purple 16/64GB', 8388736, 64, 16),
#  (19, 14474000, 'vivo X50 Pro Purple 12/128GB', 8388736, 128, 12),
#  (19, 14730000, 'vivo X50 Pro Gold 16/64GB', 16777215, 64, 16),
#  (19, 15630000, 'vivo X50 Pro Gold 12/128GB', 16777215, 128, 12),
#  (19, 16836000, 'vivo X50 Pro Gold 6/512GB', 16777215, 512, 6),
#  (20, 9938000, 'vivo X50 Black 8/64GB', 0, 64, 8),
#  (20, 9666000, 'vivo X50 Gold 8/64GB', 16777215, 64, 8),
#  (20, 11602000, 'vivo X50 Gold 16/256GB', 16777215, 256, 16),
#  (20, 9908000, 'vivo X50 Gold 6/512GB', 16777215, 512, 6)]

# %%
# Fake tech specs data
"""
INSERT INTO 
technical_spec(name, description)
VALUES
('OS', 'He dieu hanh'),
('CPU', 'Bo xu ly trung tam'),
('RAM', 'Bo nho tam'),
('ROM', 'Bo nho trong'),
('Display Size', 'Kich co man hinh'),
('Display Refresh Rate', 'Tan so quet man hinh'),
('Display Technology', 'Cong nghe man hinh'),
('Display Resolution', 'Do phan giai'),
('Battery', 'Dung luong pin'),
('Weight', 'Trong luong'),
"""

# for each phone model options, generate the 7 tech specs data with this pattern:
# the OS is the same for all phone models from the same manufacturer, either Android or iOS, depending on the manufacturer
# the CPU is either Exynos or Snapdragon for Samsung, Apple A14 Bionic, Apple A13 Bionic, Apple A12 Bionic for Apple, Snapdragon, MediaTek for Xiaomi, Snapdragon for vivo
# CPU can has different type (like Snapdragon 888, Snapdragon 865, MediaTek Dimensity 9000), and clock speed, in ghz
# RAM and Storage should be the same as the phone model option, save it as is
# Display is the same for all same phone models, with resolution, size, refresh rate, technology
# Battery is in mAh, and should be a multiple of 10, random from 3000 to 6000
# Weight is in grams, random from 150 to 300
# save the data to a list of tuples, technical_spec_option(phoneModelOptionID, techSpecID, value)
phone_tech_spec = [(0, 0, '', 0)]

for i in range(1, len(phone_model_option)):
    if PHONE_MODEL[phone_model_option[i][0]][1] == 1:
        OS = 'Android ' + str(random.randint(11, 14))
        CPU = ['Exynos 2100', 'Exynos 990', 'Exynos 9825', 'Snapdragon 888', 'Snapdragon 865', 'Snapdragon 855', 'Snapdragon 845', 'Snapdragon 835']
    elif PHONE_MODEL[phone_model_option[i][0]][1] == 2:
        OS = 'iOS ' + str(random.randint(13, 17))
        CPU = ['Apple A14 Bionic', 'Apple A13 Bionic', 'Apple A12 Bionic']
    elif PHONE_MODEL[phone_model_option[i][0]][1] >= 3:
        OS = 'Android ' + str(random.randint(11, 14))
        CPU = ['Snapdragon 888', 'Snapdragon 865', 'Snapdragon 855', 'Snapdragon 845', 'Snapdragon 835', 'MediaTek Dimensity 9000', 'MediaTek Dimensity 1200', 'MediaTek Dimensity 1100']

    # shuffle CPU options
    cpu = random.choice(CPU)

    # Display options
    resolution = random.choice(['1080x2400', '1440x3200', '1125x2436', '1242x2688', '828x1792', '1080x2376'])
    size = random.randint(4, 6) + 0.1*random.randint(0, 9)
    refreshRate = random.choice([60, 90, 120, 144, 165, 240])
    technology = random.choice(['AMOLED', 'LCD', 'OLED', 'Super AMOLED'])

    for j in range(10):
        if j == 0:
            value_shown = OS
            value = 0 if OS.split()[0] == 'Android' else 1
        elif j == 1:
            ghz = random.randint(2, 3) + 0.1*random.randint(0, 9)
            value_shown = cpu + ' ' + str(ghz) + 'GHz'
            value = round(ghz, 2)
        elif j == 2:
            value_shown = str(phone_model_option[i][5]) + 'GB'
            value = phone_model_option[i][5]
        elif j == 3:
            value_shown = str(phone_model_option[i][4]) + 'GB'
            value = phone_model_option[i][4]
        elif j == 4:
            value_shown = str(size) + 'inch'
            value = size
        elif j == 5:
            value_shown = str(refreshRate) + 'Hz'
            value = refreshRate
        elif j == 6:
            value_shown = technology
            value = 0 if technology == 'LCD' else 1
        elif j == 7:
            value_shown = resolution
            value = int(resolution[-4:])
        elif j == 8:
            battery = random.randint(300, 600)*10
            value_shown = str(battery) + 'mAh'
            value = battery
        elif j == 9:
            weight = random.randint(150, 300)
            value_shown = str(weight) + 'g'
            value = weight
        phone_tech_spec.append((i, j+1, value_shown, value))

phone_tech_spec[-20::]
# Out:
# [(85, 1, 'Android 12', 0),
#  (85, 2, 'Snapdragon 865 3.3GHz', 3.3),
#  (85, 3, '16GB', 16),
#  (85, 4, '256GB', 256),
#  (85, 5, '4.4inch', 4.4),
#  (85, 6, '240Hz', 240),
#  (85, 7, 'OLED', 1),
#  (85, 8, '1440x3200', 3200),
#  (85, 9, '3920mAh', 3920),
#  (85, 10, '268g', 268),
#  (86, 1, 'Android 13', 0),
#  (86, 2, 'Snapdragon 855 2.9GHz', 2.9),
#  (86, 3, '6GB', 6),
#  (86, 4, '512GB', 512),
#  (86, 5, '5.8inch', 5.8),
#  (86, 6, '120Hz', 120),
#  (86, 7, 'LCD', 0),
#  (86, 8, '1125x2436', 2436),
#  (86, 9, '3210mAh', 3210),
#  (86, 10, '214g', 214)]

# %%
# generate fake article data
"""
INSERT INTO
article(content)
"""

article_data = [""]

for i in range(1, len(PHONE_MODEL)):
    data = PHONE_MODEL[i][0] + ' is a great phone, with a lot of features. It has a great camera, a powerful CPU, and a beautiful display. The battery life is also very good, and the phone is very fast and responsive. Overall, I am very happy with my purchase and would recommend this phone to anyone looking for a high-end smartphone.'
    article_data.append(data)

# %%
# generate fake review
"""
phone_review(phoneModelID, phoneModelOptionID, userID, rating, likes, timePosted)
"""

phone_review = [(0, 0, 0, 0, 0, 0)]

for j in range(1, len(phone_model_option)):
    for k in range(random.randint(1, 10)):
        userID = random.randint(1, 250)
        rating = random.randint(1, 5)
        likes = random.randint(0, 200)
        # timePosted random from 2 years ago to now, format: yyyy-mm-dd hh:mm:ss
        timePosted = str(random.randint(2023, 2024)) + '-' + str(random.randint(1, 12)).zfill(2) + '-' + str(random.randint(1, 28)).zfill(2) + ' ' + str(random.randint(0, 23)).zfill(2) + ':' + str(random.randint(0, 59)).zfill(2) + ':' + str(random.randint(0, 59)).zfill(2)

        phone_review.append((phone_model_option[j][0], j, userID, rating, likes, timePosted))

# %%
# generate fake review content
"""
phone_review_detail(reviewID, content)
"""

phone_review_detail = [(0, '')]

for i in range(1, len(phone_review)):
    rating = phone_review[i][3]
    if rating > 3:
        content = 'This phone is ' + random.choice(['amazing', 'awesome', 'great', 'fantastic', 'incredible', 'outstanding', 'excellent', 'superb', 'wonderful', 'brilliant']) + '! I love the ' + random.choice(['camera', 'display', 'battery life', 'performance', 'design', 'features', 'build quality', 'software', 'price', 'value for money']) + '.'
    elif rating == 3:
        content = 'This phone is ' + random.choice(['good', 'decent', 'ok', 'fine', 'average', 'satisfactory', 'acceptable', 'not bad', 'alright', 'passable']) + '. I think the ' + random.choice(['camera', 'display', 'battery life', 'performance', 'design', 'features', 'build quality', 'software', 'price', 'value for money']) + ' could be better.'
    else:
        content = 'This phone is ' + random.choice(['bad', 'terrible', 'horrible', 'awful', 'poor', 'disappointing', 'unsatisfactory', 'subpar', 'lousy', 'dreadful']) + '. I hate the ' + random.choice(['camera', 'display', 'battery life', 'performance', 'design', 'features', 'build quality', 'software', 'price', 'value for money']) + '.'
    
    content = "Review " + str(i) + ": " + content

    phone_review_detail.append((i, content))

# %%
# generate fake phone identification data
"""
phone(phoneModelID, phoneModelOptionID, imei, customPrice, phoneCondition, status, ownedByUserID, orderID, warrantyID, warrantyUntil, inStoreID)
"""
# for each phone model option, generate 10 to 20 phone data with this pattern:
# imei is a 15-digit number, random
# phoneCondition is an enum ENUM('New', 'Used', 'Refurbished'), random with 70% New, 20% Used, 10% Refurbished
# status is an ENUM('InStore', 'Active', 'Repairing', 'Inactive'), random with 60% InStore, 39% Active, 5% Repairing, 1% Inactive
# if status is 'Active', ownedByUserID, orderID, warrantyID, warrantyUntil, inStoreID should be random
# if status is 'InStore', inStoreID should be random, the rest should be NULL
# if phoneCondition is 'New', customPrice should be PHONE_MODEL_OPTION price
# if phoneCondition is 'Used', customPrice should be PHONE_MODEL_OPTION price - random.randint(20, 50)*100000
# if phoneCondition is 'Refurbished', customPrice should be PHONE_MODEL_OPTION price - random.randint(10, 30)*100000
# orderID should be NULL if status is 'InStore', random from 1 to 150 if status is 'Active'
# warrantyID should be NULL if status is 'InStore', else should be PHONE_MODEL warrantyID (the 4th element in PHONE_MODEL)
# warrantyUntil should be NULL if status is 'InStore', else should be random from -1 to 1 year from now (2024) (format: yyyy-mm-dd)
# inStoreID should be random from 1 to 15

phone = [(0, 0, '', 0, '', '', 0, 0, 0, '', 0)]
user_list = set()
order_list = set()

import datetime
orderIDList = [i for i in range(1, 301)]
userIDList = [i for i in range(1, 251)]
storeIDList = [random.randint(1, 77) for i in range(300)]
orderTimeList = [datetime.datetime(random.randint(2023,2024), random.randint(1, 12), random.randint(1, 28), random.randint(0, 23), random.randint(0, 59), random.randint(0, 59)) for i in range(300)]

random.shuffle(userIDList)

while len(userIDList) < len(orderIDList):
    userIDList.append(random.randint(1, 250))

take = 0

for i in range(1, len(phone_model_option)):
    for j in range(random.randint(15, 20)):
        imei = str(random.randint(100000000000000, 999999999999999))
        phoneCondition = random.choices(['New', 'Used', 'Refurbished'], weights=[0.7, 0.2, 0.1])[0]
        status = random.choices(['InStore', 'Active', 'Inactive'], weights=[0.6, 0.39, 0.01])[0]
        customPrice = phone_model_option[i][1]
        if phoneCondition == 'Used':
            customPrice -= random.randint(20, 50)*100000
        elif phoneCondition == 'Refurbished':
            customPrice -= random.randint(10, 30)*100000

        if status == 'Active' or status == 'Inactive':
            warrantyID = PHONE_MODEL[phone_model_option[i][0]][4]
            if take < len(userIDList):
                ownedByUserID = userIDList[take]
                orderID = orderIDList[take]
                inStoreID = storeIDList[take]
                if warrantyID < 3:
                    warrantyUntil = orderTimeList[take] + datetime.timedelta(days=180)
                else:
                    warrantyUntil = orderTimeList[take] + datetime.timedelta(days=365)
                take += 1
                
            else:
                randomIndex = random.randint(0, len(userIDList) - 1)
                ownedByUserID = userIDList[randomIndex]
                orderID = orderIDList[randomIndex]
                inStoreID = storeIDList[randomIndex]
                if warrantyID < 3:
                    warrantyUntil = orderTimeList[randomIndex] + datetime.timedelta(days=180)
                else:
                    warrantyUntil = orderTimeList[randomIndex] + datetime.timedelta(days=365)
            
            if warrantyUntil.year == 2025:
                status = random.choices([status, 'Repairing'], weights=[0.9, 0.1])[0]
            warrantyUntil = warrantyUntil.strftime('%Y-%m-%d')
        else:
            ownedByUserID = 0
            orderID = 0
            warrantyID = 0
            warrantyUntil = '2000-01-01'
            inStoreID = random.randint(1, 77)

        phone.append((phone_model_option[i][0], i, imei, customPrice, phoneCondition, status, ownedByUserID, orderID, warrantyID, warrantyUntil, inStoreID))
print(take)
# Out:
# 300

# %%
import datetime

# CREATE TABLE order (
#   orderID INT NOT NULL AUTO_INCREMENT,
#   orderTime DATETIME NOT NULL,
#   shippedTime DATETIME,
#   status ENUM('Pending', 'Preparing', 'Delivering', 'Completed', 'Cancelled') NOT NULL,
#   comment TEXT,
#   userID INT NOT NULL,
#   fromStoreID INT,
#   employeeID INT,
#   PRIMARY KEY (orderID)
# )

# generate fake order data
"""
order(orderTime, shippedTime, status, userID, fromStoreID, employeeID)
order_detail(orderID, phoneID, serviceID, promotionID, originalPrice, finalPrice)
"""

order = [(0, 0, '', 0, 0, 0)]

for i in range(1, 301):
    orderTime = orderTimeList[i-1]
    shippedTime = orderTime + datetime.timedelta(days=random.randint(1, 15), seconds=random.randint(1, 86399))
    userID = userIDList[i-1]
    fromStoreID = storeIDList[i-1]
    employeeID = 250 + fromStoreID
    if orderTime < datetime.datetime(2024, 12, 10):
        status = 'Completed'
        shippedTime = shippedTime.strftime('%Y-%m-%d %H:%M:%S')
    elif orderTime < datetime.datetime(2024, 12, 20):
        shippedTime = None
        status = 'Delivering'
    elif orderTime < datetime.datetime(2024, 12, 25):
        shippedTime = None
        status = 'Preparing'
    else:
        shippedTime = None
        status = 'Pending'

    order.append((orderTime.strftime('%Y-%m-%d %H:%M:%S'), shippedTime, status, userID, fromStoreID, employeeID))

# %%
# generate fake order data
"""
order_detail(orderID, phoneID, serviceID, promotionID, originalPrice, finalPrice)
"""

phone2 = phone
order_detail = [(0, 0, 0, 0, 0)]
# show only phone with orderId
for i in range(1, len(phone2)):
    if phone2[i][7] == 0:
        continue
    phoneModelID = phone2[i][0]
    orderID = phone2[i][7]
    orderTime = orderTimeList[orderID-1]
    serviceID = 0
    promotionID = 0
    if orderTime >= datetime.datetime(2023, 12, 22) and orderTime <= datetime.datetime(2024, 1, 1):
        promotionID = random.randint(0,1)
    elif orderTime >= datetime.datetime(2024, 8, 1) and orderTime <= datetime.datetime(2024, 9, 30):
        promotionID = random.choice([0, 2])
    elif orderTime >= datetime.datetime(2024, 11, 20) and orderTime <= datetime.datetime(2024, 11, 30):
        promotionID = random.choice([0, 3])
    elif orderTime >= datetime.datetime(2024, 4, 1) and orderTime <= datetime.datetime(2024, 7, 30) and phoneModelID > 16:
        promotionID = random.choice([0, 4])
    elif orderTime >= datetime.datetime(2024, 9, 15) and orderTime <= datetime.datetime(2024, 9, 30) and phoneModelID == 6:
        promotionID = random.choice([0, 5])
    
    originalPrice = phone2[i][3]
    finalPrice = originalPrice
    if promotionID == 1:
        finalPrice = originalPrice * 0.9
    elif promotionID == 2:
        finalPrice = originalPrice - 2000000
    elif promotionID == 3:
        finalPrice = originalPrice * 0.85
    elif promotionID == 4:
        finalPrice = originalPrice - 1000000
    elif promotionID == 5:
        if phone2[i][1] == 27:
            finalPrice = 22990000
        elif phone2[i][1] == 28:
            finalPrice = 23990000
        elif phone2[i][1] == 29:
            finalPrice = 24990000
    order_detail.append((orderID, i, serviceID, promotionID, originalPrice, int(finalPrice)))

    serviceIDList = []
    priceList = [1000000, 2000000, 3000000, 300000, 500000, 100000, 200000, 300000, 50000]
    if random.randint(0, 1) == 1:
        serviceIDList.append(random.choice([6,7,8]))
    if random.randint(0, 1) == 1:
        serviceIDList.append(9)
    if random.randint(0, 1) == 1:
        serviceIDList.append(5 if phoneModelID not in range(6,12) else 4)

    for serviceID in serviceIDList:
        originalPrice = priceList[serviceID - 1]
        finalPrice = originalPrice
        if serviceID in range(4,6) and orderTime >= datetime.datetime(2024, 3, 1) and orderTime <= datetime.datetime(2024, 9, 30):
            promotionID = random.choice([0,6])
            finalPrice = 0 if promotionID == 6 else originalPrice
        elif serviceID in range(6,9) and orderTime >= datetime.datetime(2024, 3, 1) and orderTime <= datetime.datetime(2024, 9, 30):
            promotionID = random.choice([0,7])
            finalPrice = (originalPrice*0.7) if promotionID == 7 else originalPrice
        
        order_detail.append((orderID, i, serviceID, promotionID, originalPrice, int(finalPrice)))

# sort by orderID
order_detail = sorted(order_detail, key=lambda x: x[0])

# %%
# clean up store data
STORE_DATA = [
('89A Nguyễn Đình Chiểu, Q3, TP.HCM', 18, 'HCM - 89A Nguyễn Đình Chiểu', '(08)38.102.102', '89a-nguyen-dinh-chieu-q3-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Nguyen-Dinh-Chieu.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.78, 106.692, 3),
('330 Cộng Hòa, Q. Tân Bình, TP.HCM', 30, 'HCM - 300 Cộng Hòa', '(08)38.102.102', '330-cong-hoa-q-tan-binh-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Cong-Hoa.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.8022, 106.646, 3),
('26 Phan Đăng Lưu, Q. Bình Thạnh, TP.HCM', 51, 'HCM-26 Phan Đăng Lưu', '(08)38.102.102', '26-phan-dang-luu-q-binh-thanh-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-26-Phan-Dang-Luu.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.8035, 106.689, 3),
('182 A Nguyễn Thị Minh Khai, Q3, TP.HCM', 18, 'HCM-182 Nguyễn Thị Minh Khai', '(08)38.102.102', '182-a-nguyen-thi-minh-khai-q3-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Nguyen-Thi-Minh-Khai.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.7759, 106.691, 3),
('708 Nguyễn Trãi , Quận 5, TP.HCM', 20, 'HCM - 708 Nguyễn Trãi', '(08)38.102.102', '708-nguyen-trai-quan-5-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Nguyen-Trai.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.753, 106.661, 3),
('121 -123 Võ Văn Ngân, P.Linh Chiểu, Q.Thủ Đức, TPHCM', 28, 'HCM-121 Võ Văn Ngân', '(08)38.102.102', '121-123-vo-van-ngan-plinh-chieu-qthu-duc-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Vo-Van-Ngan.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.8505, 106.761, 3),
('222 Trường Chinh ,  P.Tân Hưng Thuận, Q12, TP.HCM', 27, 'HCM-222 Trường Chinh', '(08)38.102.102', '222-truong-chinh-ptan-hung-thuan-q12-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-222-Truong-Chinh.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.8311, 106.623, 3),
('11A Thái Hà, P.Trung Liệt, Q. Đống Đa, Hà Nội', 37, 'HN -11A Thái Hà', '(04)37.757.757', '11a-thai-ha-ptrung-liet-q-dong-da-ha-noi', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HN-Thai-Ha.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 21.013, 105.82, 5),
('A12 Trần Hưng Đạo, P. Thắng Lợi, TP. BMT , Đắk Lắk', 833, 'BMT - A12 Trần Hưng Đạo', '(0511)3.757.757', 'a12-tran-hung-dao-p-thang-loi-tp-bmt-dak-lak', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Dac-Lak-12-Tran-Hung-Dao.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 12.6858, 108.049, 6),
('310 Trường Chinh, P.13, Quận Tân Bình, TPHCM', 30, 'HCM - 310 Trường chinh', '(08)38.102.102', '310-truong-chinh-p13-quan-tan-binh-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap
 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Tay-Ninh-583-CMT8.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 11.3093, 106.106, 146),
('313 đường Nguyễn Huệ, KP III, Phường 2, TX. Gò Công, tỉnh Tiền Giang', 1370, 'TG - Gò Công', '(08)38.102.102', '313-duong-nguyen-hue-kp-iii-phuong-2-tx-go-cong', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Tien-Giang-313-Nguyen-Hue.jpg', '', '8 giờ - 22 giờ 30 (kể cả chủ nhật và ngày lễ)', 10.3593, 106.676, 151),
('359B Lê Văn Sỹ, P.1, Q.Tân Bình, TPHCM', 30, 'HCM - 359B Lê Văn Sỹ', '(08)38.102.102', '359b-le-van-sy-p1-qtan-binh-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Le-Van-Sy.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.7969, 106.665, 3),
('21 Điện Biên Phủ, Khóm 4, P.6, Thị xã Trà Vinh, Trà Vinh', 1383, 'TV - Trà Vinh', '(08)38.102.102', '21-dien-bien-phu-khom-4-p6-thi-xa-tra-vinh-tra', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Tra-Vinh-21-Dien-Bien-Phu.jpg', '', '8 giờ - 22 giờ 30 (kể cả chủ nhật và ngày lễ)', 9.92437, 106.341, 152),
('77 Nguyễn Trung Trực, P.Vĩnh Bảo, TP. Rạch Giá, Kiên Giang', 868, 'RG - 77 Nguyễn Trung Trực', '(08)38.102.102', '77-nguyen-trung-truc-pvinh-bao-tp-rach-gia-kien', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Kien-Giang-77-Nguyen-Trung-Truc.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.0051, 105.087, 126),
('222 Yersin, P. Phú Cường, TP. Thủ Dầu Một, T.Bình Dương', 761, 'BD - 222 Yersin', '(08)38.102.102', '222-yersin-p-phu-cuong-tp-thu-dau-mot-tbinh-duo', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/BD-Yersin.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.9838, 106.665, 109),
('159 –161 Lê Văn Việt, Phường Hiệp Phú, Quận 9, TP.HCM', 24, 'HCM - 159_161 Lê Văn Việt', '(08)38.102.102', '159-161-le-van-viet-phuong-hiep-phu-quan-9-tph', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Le-Van-Viet.jpg', '', '8 giờ - 22 giờ 30 (kể cả chủ nhật và ngày lễ)', 10.8458, 106.779, 3),
('380A Nguyễn Trung Trực, P. Vĩnh Lạc, TP. Rạch Giá, Kiên Giang', 868, 'KGI - 380A Nguyễn Trung Trực', '(08)38.102.102', '380a-nguyen-trung-truc-p-vinh-lac-tp-rach-gia-k', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Kien-Giang-380A-Nguyen-Trung-Truc.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 9.99748, 105.092, 126),
('171 Nguyễn Sơn, P. Phú Thạnh, Q. Tân Phú, TP.HCM', 33, 'HCM-171 Nguyễn Sơn', '(08)38.102.102', '171-nguyen-son-p-phu-thanh-q-tan-phu-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Nguyen-Son.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.7827, 106.627, 3),
('215 Xã Đàn, P.Nam Đồng, Q.Đống Đa, TP. Hà Nội', 37, 'HN - 215 Xã Đàn', '(04)37.757.757', '215-xa-dan-pnam-dong-qdong-da-tp-ha-noi', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap
 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Can-Tho-84-30-Thang-4.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.0297, 105.78, 7),
('Số C4/21 khu phố III, Thị trấn Tân Túc, Huyện Bình Chánh, TP. HCM', 36, 'HCM - Tân Túc', '(08)38.102.102', 'so-c4-21-khu-pho-iii-thi-tran-tan-tuc-huyen-binh', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-C4-21-Binh-Chanh.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 10.6796, 106.587, 3),
('Số 908 đường Tôn Đức Thắng, P. Hòa Khánh Bắc, Q. Liên Chiểu,  TP. Đà Nẵng', 853, 'ĐN - Tôn Đức Thắng', '(0511)3.757.757', 'so-908-duong-ton-duc-thang-p-hoa-khanh-bac-q-lie', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Da-Nang-Ton-Duc-Thang.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 16.0715, 108.151, 9),
('67 Nguyễn Tất Thành,TT Đắk Mil, Huyện Đắk Mil. Tỉnh Đắk Nông', 978, 'ĐKN - Nguyễn Tất Thành (Đắk Mil)', '(0511)3.757.757', '67-nguyen-tat-thanh-tt-dak-mil-huyen-dak-mil-tinh', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Dac-Nong-67-Nguyen-Tat-Thanh.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 12.4499, 107.622, 113),
('Số 390 – 392 – 394 – 396 Lê Duẩn, Phường Eatam, TP. BMT, Tỉnh ĐăkLăk', 833, 'BMT - Lê Duẩn (Buôn Mê Thuộc)', '(0511)3.757.757', 'so-390-392-394-396-le-duan-phuong-eatam-tp', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Dac-Lak-390-Le-Duan.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 12.6574, 108.028, 6),
('225–227 Lý Thường Kiệt,  P. Cẩm Phô, TP. Hội An, Quảng Nam', 1232, 'QN - Lý Thường Kiệt (Hội An)', '(0511)3.757.757', '225-227-ly-thuong-kiet-p-cam-pho-tp-hoi-an-qua', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Quang-Nam-225-Ly-Thuong-Kiet.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 15.8843, 108.325, 140),
('1-1A Nguyễn Kiệm, P3, Q. Gò Vấp, TP.HCM', 29, 'HCM - Nguyễn Kiệm', '(08)38.102.102', '1-1a-nguyen-kiem-p3-q-go-vap-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Nguyen-Kiem.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 10.8144, 106.679, 3),
('189 Nguyễn Oanh, F.10, Quận Gò Vấp, TP.HCM', 29, 'HCM-189 Nguyễn Oanh', '(08)38.102.102', '189-nguyen-oanh-f10-quan-go-vap-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Nguyen-Oanh.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.8348, 106.676, 3),
('759 Cách MạngTháng 8, F 6, Q Tân Bình, TP.HCM', 30, 'HCM  - 759 Cách MạngTháng 8', '(08)38.102.102', '759-cach-mangthang-8-f-6-q-tan-binh-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-CMT8.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.788, 106.663, 3),
('312 - 312A Thống Nhất, Phường Phủ Hà, TP Phan Rang Tháp Chàm, Ninh Thuận', 1195, 'NT - Phan Rang', '(0511)3.757.757', '312-312a-thong-nhat-phuong-phu-ha-tp-phan-rang-t', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Ninh-Thuan-312-Thong-Nhat.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 11.5709, 108.991, 136),
('Số 2, đường Đặng Thái Thân, P. Cửa Nam, Tp. Vinh, Nghệ An', 1181, 'Vinh ( nghệ An)', '(0511)3.757.757', 'so-2-duong-dang-thai-than-p-cua-nam-tp-vinh-ng', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Nghe-An-2-Dang-Thai-Than.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 18.667, 105.665, 134),
('157 Trần Hưng Đạo, P.Trần Hưng Đạo, TP. Nam Định, Nam Định', 1156, 'NĐ - Trần Hưng Đạo', '(04)37.757.757', '157-tran-hung-dao-ptran-hung-dao-tp-nam-dinh-na', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Nam-Dinh-157-Tran-Hung-Dao.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 20.4262, 106.176, 133),
('Số 01 Hòn Chồng, Phường Vĩnh Phước, Tp Nha Trang, Tình Khánh Hòa', 1094, 'KH - Nha Trang', '(0511)3.757.757', 'so-01-hon-chong-phuong-vinh-phuoc-tp-nha-trang', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Khanh-Hoa-1-Hon-Chong.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 12.2493, 109.183, 125),
('Số 288, đường Hai Bà Trưng, P. Hùng Vương, TX Phúc Yên, Vĩnh Phúc', 1400, 'VP - Hai Bà Trưng (Phúc Yên)', '(04)37.757.757', 'so-288-duong-hai-ba-trung-p-hung-vuong-tx-phuc', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Vinh-Phuc-288-Hai-Ba-Trung.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 21.2312, 105.702, 155),
('Số 1 và 3 Nguyễn Trãi, P. Ngọc Trạo, TX Bỉm Sơn, tỉnh Thanh Hóa', 1331, 'TH - Nguyễn Trãi (Bỉm Sơn)', '(0511)3.757.757', 'so-1-va-3-nguyen-trai-p-ngoc-trao-tx-bim-son-ti', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Thanh-Hoa-1-Nguyen-Trai.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 20.0847, 105.858, 149),
('Đường Tỉnh Lộ 10, xã Đức Hòa Hạ, Huyện Đức Hòa, Long An', 1143, 'LA - Bình Tả 2', '(08)38.102.102', 'duong-tinh-lo-10-xa-duc-hoa-ha-huyen-duc-hoa-lo', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Long-An-Nga-3-Tan-Tuc.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 10.8115, 106.475, 132),
('Thôn Phan Xá, Xã Uy nổ, Huyện Đông Anh, Hà Nội', 46, 'HN - Thôn Phan Xá', '(04)37.757.757', 'thon-phan-xa-xa-uy-no-huyen-dong-anh-ha-noi', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap
 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Thai-Binh-1-Quang-Trung.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 20.4441, 106.338, 147),
('670 Âu Cơ, P.10, Q. Tân Bình, Tp. HCM', 30, 'HCM - Âu Cơ', '(08)38.102.102', '670-au-co-p10-q-tan-binh-tp-hcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Au-Co.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 10.786, 106.642, 3),
('01 Hùng Vương, Phường 1, TP. Đông Hà, Quảng Trị', 1276, 'QTR - Hùng Vương (Quảng Trị)', '(0511)3.757.757', '01-hung-vuong-phuong-1-tp-dong-ha-quang-tri', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Quang-Tri-1-Hung-Vuong.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 16.8142, 107.101, 143),
('389 Ngọc Hồi, Văn Điển,  Hà Nội', 49, 'HNO - Ngọc Hồi', '(04)37.757.757', '389-ngoc-hoi-van-dien-ha-noi', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HN-Ngoc-Hoi.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 20.9479, 105.844, 5),
('229 Nguyễn Thị Tú, P.Bình Hưng Hòa B, Q.Bình Tân, Tp.HCM', 31, 'HCM - 229 Nguyễn Thị Tú', '(08)38.102.102', '229-nguyen-thi-tu-pbinh-hung-hoa-b-qbinh-tan-tp', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Nguyen-Thi-Tu.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.8156, 106.594, 3),
('848 Lạc Long Quân,P.8, Quận Tân Bình, TPHCM', 30, 'HCM - Lạc Long Quân', '(08)38.102.102', '848-lac-long-quan-p8-quan-tan-binh-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Lac-Long-Quan.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.7815, 106.65, 3),
('176 Nguyễn Tri Phương,P.9, Quận 5, TPHCM', 20, 'HCM - Nguyễn Tri Phương', '(08)38.102.102', '176-nguyen-tri-phuong-p9-quan-5-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Nguyen-Tri-Phuong.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.7597, 106.669, 3),
('160 Hà Huy Tập, P. Hà Huy Tập, Tp. Hà Tĩnh, Tỉnh Hà Tĩnh', 1041, '8_HTI - Hà Huy Tập (Hà Tĩnh)', '(0511)3.757.757', '160-ha-huy-tap-p-ha-huy-tap-tp-ha-tinh-tinh-ha', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Ha-Tinh-160-Ha-Huy-Tap.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 18.3336, 105.9, 120),
('18 Cách mạng Tháng 8, Ấp Chánh Lộc, Xã Chánh Mỹ, TP.Thủ Dầu Một, Bình Dương', 761, '6_BDU - Thủ Dầu Một', '(08)38.102.102', '18-cach-mang-thang-8-ap-chanh-loc-xa-chanh-my-t', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/BD-CMT8.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.9916, 106.651, 109),
('214 Phan chu Trinh, Phường Phước Hòa, TP.Tam Kỳ, Quảng Nam', 1240, '9_QNA - Phan Chu Trinh', '(0511)3.757.757', '214-phan-chu-trinh-phuong-phuoc-hoa-tptam-ky-qu', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Quang-Nam-214-Phan-Chau-Trinh.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 15.5697, 108.488, 140),
('Khu phố 3, TT Trảng Bom, H. Trảng Bom, Đồng Nai', 749, 'ĐNai - Trảng Bom', '(08)38.102.102', 'khu-pho-3-tt-trang-bom-h-trang-bom-dong-nai', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Dong-Nai-KP3-Trang-Bom.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.9533, 107.004, 8),
('178 Nguyễn Huệ, P.2, TP. Cao Lãnh, tỉnh Đồng Tháp', 993, 'ĐT - Cao Lãnh', '(08)38.102.102', '178-nguyen-hue-p2-tp-cao-lanh-tinh-dong-thap', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Dong-Thap-178-Nguyen-Hue.jpg', '', '8 giờ - 22 giờ 30 (kể cả chủ nhật và ngày lễ)', 10.4573, 105.638, 115),
('292 Quốc lộ 80, khóm 4, P. 1, TX. Sa Đéc, tỉnh Đồng Tháp', 1000, 'ĐT - Sa Đéc', '(08)38.102.102', '292-quoc-lo-80-khom-4-p-1-tx-sa-dec-tinh-dong', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Dong-Thap-292-Nguyen-Sinh-Sac.jpg', '', '8 giờ - 22 giờ 30 (kể cả chủ nhật và ngày lễ)', 10.2904, 105.767, 115),
('763 Điện Biên, Tổ 48,P. Minh Tân, TP Yên Bái, Tỉnh Yên Bái', 1413, '1_YBA - Điện Biên (Yên Bái)', '(04)37.757.757', '763-dien-bien-to-48-p-minh-tan-tp-yen-bai-tinh', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Yen-Bai-763-Dien-Bien.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 21.7151, 104.905, 156),
('93B đường 2/9, khóm Hưng Đạo Vương, P.1, TP.Vĩnh Long, Tỉnh Vĩnh Long', 1396, 'VL - Vĩnh Long', '(08)38.102.102', '93b-duong-2-9-khom-hung-dao-vuong-p1-tpvinh-lon', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Vinh-Long-93-2-Thang-9.jpg', '', '8 giờ - 22 giờ 30 (kể cả chủ nhật và ngày lễ)', 10.2503, 105.974, 154),
('621 Quang Trung, Tổ 2, P.Tây Sơn, TX. An Khê, Tỉnh Gia Lai', 1005, 'GLA - Quang Trung', '(0511)3.757.757', '621-quang-trung-to-2-ptay-son-tx-an-khe-tinh-g', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Gia-Lai-621-Quang-Trung.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 13.954, 108.652, 116),
('482 Hồng Bàng, Phường 16, Quận 11, TP.HCM', 26, 'HCM - Hồng Bàng', '(08)38.102.102', '482-hong-bang-phuong-16-quan-11-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-Hong-Bang.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 10.7538, 106.648, 3),
('Số 34,Tổ 2, Khu Xuân Hà, Thị Trấn Xuân Mai, Huyện Chương Mỹ, Hà Nội', 819, 'HNO - Xuân Mai', '(04)37.757.757', 'so-34-to-2-khu-xuan-ha-thi-tran-xuan-mai-huyen', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap
 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Hai-Phong-126-Lach-Tray.jpg', '', '8h - 22h30 (kể cả thứ 7 & CN)', 20.8461, 106.691, 101),
('Số 487 Quang Trung, Phường Quang Trung, TP Uông Bí, Tỉnh Quảng Ninh', 1270, '9_QNI - Quang Trung (Uông Bí)', '(04)37.757.757', 'so-487-quang-trung-phuong-quang-trung-tp-uong-bi', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Quang-Ninh-487-Quang-Trung.jpg', '', '8h - 22h30 (kể cả thứ 7 & CN)', 21.0345, 106.77, 142),
('Số 1 Lò Văn Giá, P. Chiềng Lề, TP.Sơn La, Sơn La', 1299, '8_SLA - Lò Văn Giá (Sơn La)', '(04)37.757.757', 'so-1-lo-van-gia-p-chieng-le-tpson-la-son-la', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Son-La-1-Lo-Van-Gia.jpg', '', '8h - 22h30 (kể cả thứ 7 & CN)', 21.3425, 103.909, 145),
('Tổ 2, Thị Trấn Đông Hưng, Huyện Đông Hưng, Tỉnh Thái Bình', 1313, '8_THB - Đông Hưng (Thái Bình)', '(04)37.757.757', 'to-2-thi-tran-dong-hung-huyen-dong-hung-tinh-th', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Thai-Binh-Dong-Hung.jpg', '', '8h - 22h30 (kể cả thứ 7 & CN)', 20.5504, 106.356, 147),
('4/25, ấp Nam Thới, xã Thới Tam Thôn, Huyện Hóc Môn, TP.HCM', 32, 'HCM - Hóc Môn', '(08)38.102.102', '4-25-ap-nam-thoi-xa-thoi-tam-thon-huyen-hoc-mon', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-4-25-Nam-Thoi.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.8881, 106.601, 3),
('số 1 Kim Đồng, Phường Hợp Giang, TP.Cao Bằng, Cao Bằng', 965, '1_CBA - Kim Đồng (Cao Bằng)', '(04)37.757.757', 'so-1-kim-dong-phuong-hop-giang-tpcao-bang-cao-b', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Cao-Bang-1-Kim-Dong.jpg', '', '8h - 22h30 (kể cả thứ 7 & CN)', 22.6655, 106.261, 112),
('57/6 - 57/8 Lê Thị Hồng gấm, Phường 6, TP. Mỹ Tho, Tiền Giang', 1373, '2_TGI - Lê Thị Hồng Gấm', '(08)38.102.102', '57-6-57-8-le-thi-hong-gam-phuong-6-tp-my-tho-ti', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Tien-Giang-57-Le-Thi-Hong-Gam.jpg', '', '8h - 22h30 (kể cả thứ 7 & CN)', 10.3506, 106.343, 151),
('6/52 Nguyễn An Ninh, thị trấn Dĩ An, huyện Dĩ An, Bình Dương', 860, 'BD - Dĩ An', '(08)38.102.102', '6-52-nguyen-an-ninh-thi-tran-di-an-huyen-di-an', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/BD-Nguyen-An-Ninh.jpg', '', '8 giờ - 22 giờ 30 (kể cả chủ nhật và ngày lễ)', 10.9079, 106.77, 109),
('171 đường DT 745, KP Long Thới, thị trấn Lái Thiêu, H.Thuận An, Bình Dương', 863, 'BD - Lái Thiêu', '(08)38.102.102', '171-duong-dt-745-kp-long-thoi-thi-tran-lai-thieu', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap
 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Dong-Nai-54-Phuong-Lam.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 11.2859, 107.489, 8),
('650 Trường Chinh, P.15, Q.Tân Bình, TP.HCM', 30, 'HCM - 650 Trường Chinh', '(08)38.102.102', '650-truong-chinh-p15-qtan-binh-tphcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-650-Truong-Chinh.jpg', '', '8 giờ - 22 giờ 30 (kể cả chủ nhật và ngày lễ)', 10.8049, 106.635, 3),
('136 Nguyễn Thái Học, P.Phạm Ngũ Lão, Q.1, TP. HCM', 16, 'HCM - 136 Nguyễn Thái Học', '(08)38.102.102', '136-nguyen-thai-hoc-ppham-ngu-lao-q1-tp-hcm', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HCM-136-Nguyen-Thai-Hoc.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 10.7692, 106.695, 3),
('108 đường  Xương Giang, P.Trần Phú, Tp. Bắc Giang, Bắc Giang', 893, '1_BGI - Xương Giang (Bắc Giang)', '(04)37.757.757', '108-duong-xuong-giang-ptran-phu-tp-bac-giang-ba', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Bac-Giang-Xuong-Giang.jpg', '', '8h - 22h30 (cả ngày lễ & CN)', 21.2791, 106.193, 103),
('1-3-5 Trần Nhân Tông, P.Quán Trữ, Q.Kiến An, TP.Hải Phòng', 878, '8_HPH - Trần Nhân Tông', '(04)37.757.757', '1-3-5-tran-nhan-tong-pquan-tru-qkien-an-tphai-p', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Hai-Phong-1-Tran-Nhan-Tong.jpg', '', '8h - 22h30 (kể cả CN & ngày lễ)', 20.8216, 106.649, 101),
('Số 261 Phan Đình Phùng ,P.2 , TP.Đà Lạt , T.Lâm Đồng', 1111, 'LĐ - Đà Lạt', '(08)38.102.102', 'so-261-phan-dinh-phung-p2-tpda-lat-tlam-dong', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Lam-Dong-261-Phan-Dinh-Phung.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 11.9491, 108.436, 129),
('185  Hùng Vương, P.An Cựu,TP. Huế, Tỉnh Thừa Thiên Huế', 1358, '9_TTH - Hùng Vương (Huế)', '(0511)3.757.757', '185-hung-vuong-pan-cuu-tp-hue-tinh-thua-thien-hu', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/TTH-185-Hung-Vuong.jpg', '', '8h - 22h30 (kể cả CN & ngày lễ)', 16.455, 107.601, 150),
('Quốc Lộ 32, 18 Phố Nhổn, Xã Xuân Phương, H. Từ Liêm, TP. Hà Nội', 50, '1_HNO - Phố Nhổn', '(04)37.757.757', 'quoc-lo-32-18-pho-nhon-xa-xuan-phuong-h-tu-liem', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HN-QL32-Pho-Nhon.jpg', '', '8h - 22h30 (kể cả CN & ngày lễ)', 21.0536, 105.734, 5),
('Số 497 Đường Nguyễn Trãi, Q. Thanh Xuân, TP. Hà Nội', 45, '1_HNO - Nguyễn Trãi', '(04)37.757.757', 'so-497-duong-nguyen-trai-q-thanh-xuan-tp-ha-noi', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HN-Nguyen-Trai.jpg', '', '8h - 22h30 (kể cả CN & ngày lễ)', 20.988, 105.798, 5),
('456-456A-458 Bạch Mai, P.Trương Công Định, Q.Hai Bà Trưng, Hà Nội', 40, 'HN - 456 Bạch Mai', '(04)37.757.757', '456-456a-458-bach-mai-ptruong-cong-dinh-qhai-ba', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/HN-Bach-Mai.jpg', '', '8 giờ - 22 giờ 30 (Kể cả CN & Ngày lễ)', 20.9971, 105.85, 5),
('127 Trần Hưng Đạo,P.Đồng Phú, TP. Đồng Hới, Quảng Bình', 1220, 'QBI - Trần Hưng Đạo', '(0511)3.757.757', '127-tran-hung-dao-pdong-phu-tp-dong-hoi-quang-bi', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Quang-Binh-127-Tran-Hung-Dao.jpg', '', '7 giờ 30 - 22 giờ 30 (kể cả CN và ngày lễ)', 17.4694, 106.614, 139),
('148B ấp 2, Thị Trấn Hộ Phòng, Huyện Giá Rai, Tỉnh Bạc Liêu', 912, 'BLI - Hộ Phòng', '(08)38.102.102', '148b-ap-2-thi-tran-ho-phong-huyen-gia-rai-tinh', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Bac-Lieu-148-Ho-Phong.jpg', '', '8 giờ - 22 giờ 30 (kể cả chủ nhật và ngày lễ)', 9.22613, 105.413, 105),
('Tổ 65 Phường Cẩm Thủy, TP. Cẩm Phả, Quảng Ninh', 1260, '8_QNI - Cẩm Thủy', '(04)37.757.757', 'to-65-phuong-cam-thuy-tp-cam-pha-quang-ninh', 'cskh@thegioididong.com', 'http://cdn.tgdd.vn/StoreMap/Quang-Ninh-617-Tran-Phu.jpg', '', '8h - 22h30 (kể cả CN & ngày lễ)', 21.0098, 107.268, 142)
]

store_data = []

for store in STORE_DATA:
    store_data.append((store[0], store[1], store[2], store[3], store[9], store[10], store[11]))

# take all stores in Hanoi, separate them from other stores
store_data_HN = []
store_data_oth = []
for store in store_data:
    if store[0].find('Hà Nội') != -1:
        store_data_HN.append(store)
    else:
        store_data_oth.append(store)

# take 60 random stores
random.shuffle(store_data_oth)
store_data_oth = store_data_oth[:60]

store_data = store_data_HN + store_data_oth

len(store_data)
# Out:
# 77

# %%
# generate fake userdata
"""
user(fullName, email, phone, address, provinceID, districtID, role, storeID)
"""
# email could be any, random using normal string
# fullName could be any, but please using random from the given list of first name, lastname, surname
# phone could be any, start with +84 then add 9 more digits
# address could be any, random any kind of string
# storeID could be any, random from 1-77
# provinceID could be any, random from the one in store_data[storeID]
# districtID could be any, random from the one in store_data[storeID]
# role is an enum ENUM('Customer', 'Employee'), random between

import string

user_data = [('', '', '', 0, 0, 'Customer', 0)]
LAST_NAME_LIST = ['Nguyễn', 'Trần', 'Lê', 'Phạm', 'Hoàng', 'Huỳnh', 'Phan', 'Vũ', 'Võ', 'Đặng', 'Bùi', 'Đỗ', 'Hồ', 'Ngô', 'Dương', 'Lý', 'Đinh', 'Trịnh', 'Lý', 'Lương', 'Kiều', 'Mai', 'Tô', 'Tôn']
SURNAME_LIST = ['Thị', 'Văn', 'Đình', 'Hữu', 'Thành', 'Hồng', 'Quốc', 'Minh', 'Hải', 'Hà', 'Hương', 'Phương', 'Thảo', 'Thu', 'Hoa', 'Huy']
FIRST_NAME_LIST = ['Anh', 'Bình', 'Cường', 'Dũng', 'Đức', 'Hải', 'Hùng', 'Hưng', 'Khánh', 'Linh', 'Long', 'Minh', 'Nam', 'Phúc', 'Quân', 'Quang', 'Sơn', 'Tùng', 'Tuấn', 'Việt', 'Vũ', 'Xuân', 'Yến']
                
for i in range(250):
    storeID = random.randint(1, 77)
    provinceID = store_data[storeID - 1][6]
    districtID = store_data[storeID - 1][1]
    user_data.append((random.choice(LAST_NAME_LIST) + ' ' + random.choice(SURNAME_LIST) + ' ' + random.choice(FIRST_NAME_LIST) ,
                        ''.join(random.choice(string.ascii_lowercase) for i in range(10)) + '@gmail.com',
                       '+84' + ''.join(random.choice(string.digits) for i in range(9)), 
                       ''.join(random.choice(string.ascii_lowercase) for i in range(20)),
                         provinceID, districtID,
                           'Customer',
                           storeID  ))

for i in range(77):
    storeID = i + 1
    provinceID = store_data[storeID - 1][6]
    districtID = store_data[storeID - 1][1]
    user_data.append((random.choice(LAST_NAME_LIST) + ' ' + random.choice(SURNAME_LIST) + ' ' + random.choice(FIRST_NAME_LIST) ,
                        ''.join(random.choice(string.ascii_lowercase) for i in range(10)) + '@gmail.com',
                       '+84' + ''.join(random.choice(string.digits) for i in range(9)), 
                       ''.join(random.choice(string.ascii_lowercase) for i in range(20)),
                         provinceID, districtID,
                           'Employee',
                           storeID  ))

user_data[-2:]
# Out:
# [('Vũ Đình Việt',
#   'nlngcfycil@gmail.com',
#   '+84144524449',
#   'pnefcrusvolfnaezqixa',
#   3,
#   31,
#   'Employee',
#   76),
#  ('Ngô Văn Long',
#   'uvhwsffllj@gmail.com',
#   '+84133520877',
#   'sqwpgvydtxgchjaonbjt',
#   102,
#   885,
#   'Employee',
#   77)]

# %%
import os
if not os.path.exists('data'):
    os.makedirs('data')

# %%
# export to txt
with open('data/phone_model_option.txt', 'w') as f:
    for item in phone_model_option[1:]:
        f.write("%s,\n" % str(item[:-2]))

with open('data/phone_tech_spec.txt', 'w') as f:
    for item in phone_tech_spec[1:]:
        f.write("%s,\n" % str(item))

# %%
with open('data/article_data.txt', 'w') as f:
    for item in article_data[1:]:
        f.write("('%s'),\n" % item)

# %%
with open('data/phone_review.txt', 'w') as f:
    for item in phone_review[1:]:
        f.write("%s,\n" % str(item))

# %%
with open('data/phone_review_detail.txt', 'w') as f:
    for item in phone_review_detail[1:]:
        f.write("(%s, '%s'),\n" % item)

# %%
with open('data/phone.txt', 'w') as f:
    for item in phone[1:]:
        f.write("%s,\n" % str(item))

# %%
with open('data/store_data.txt', 'w', encoding='utf-8') as f:
    for item in store_data:
        f.write("%s,\n" % str(item))

# %%
with open('data/user_data.txt', 'w', encoding='utf-8') as f:
    for item in user_data[1:]:
        f.write("%s,\n" % str(item))

# %%
with open('data/order_data.txt', 'w', encoding='utf-8') as f:
    for item in order[1:]:
        f.write("%s,\n" % str(item))

# %%
with open('data/order_detail_data.txt', 'w', encoding='utf-8') as f:
    for item in order_detail[1:]:
        f.write("%s,\n" % str(item))
